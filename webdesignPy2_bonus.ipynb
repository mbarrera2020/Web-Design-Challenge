# %% [markdown]
# #### Web-Design-Challenge - Bonus
# #Python program to convert CSV file to HTML Table
# ##Author: Maria Barrera
# ##Date: 03/07/2021
#
# ##Note: This is for the bonus data:  cities_2bonus.csv

# %%
import pandas as pd 
  
# to read csv file named "cities" 
cities_data2bonus = pd.read_csv("Resources/cities_2bonus.csv") 
cities_data2bonus
# Out:
#      City_ID           City  Cloudiness Country        Date  Humidity  \
# 0       9505      carnarvon           0      AU  1612811945       100
# 1    2011314    port alfred          79      ZA  1612812024        88
# 2       8303        ushuaia           0      AR  1612811989        55
# 3       5832   saint george           1      US  1612811821        27
# 4       8926     nikolskoye           0      RU  1612812012        84
# ..       ...            ...         ...     ...         ...       ...
# 302     8587  san cristobal          40      VE  1612812806        48
# 303     8368       itaituba          40      BR  1612812568        66
# 304     2434           atar           0      MR  1612812807        12
# 305     8675       pucallpa          40      PE  1612812572        58
# 306     8838         qovlar          90      AZ  1612812811       100
#
#          Lat       Lng  Max Temp  Wind Speed
# 0   -24.8667  113.6333    298.15        8.23
# ...

# %%
# save table as html file named: data_table.html
cities_data2bonus.to_html("data_table2bonus.html")

# %%
# assign it to a variable (string) 
html_file2bonus = cities_data2bonus.to_html()
